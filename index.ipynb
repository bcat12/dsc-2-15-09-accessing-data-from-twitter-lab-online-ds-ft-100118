# %% [markdown]
# # Data mining with Twitter API and Basic NLP - Lab
#
# ## Introduction
# In this lab, we shall use our Twitter developer account created in the previous lessson and the keys we generated to make some API calls to twitter. We shall look at a number of ways of accessing twitter data which may suit different use cases for twitter API calling. We shall also get an introduction to the `tweepy` Python library to help us with tweet mining and parsing. We shall perform some basic NLP to count the term frequencies etc.
#
# **Note:** You are encourages to consult the Twitter API documentation and `tweepy` library documentation to understand structure of tweets and their properties for accessing specific elements.
#
#
# ## Objectives
#
# You will be able to:
# * Successfully request tweet data from the Twitter API using the Tweepy library
# * Understand the structure of Twitter JSON object structure
# * Parse tweet data and perform basic text analysis using basic NLP techniques
# * Visualize hashtags, mentions from tweets using number of visualization techniques
# * Collect and Parse tweets for a number of use cases

# %% [markdown]
# ## `tweepy`
#
# Tweepy is open-source library, hosted on GitHub and enables Python to communicate with Twitter platform and use its API. Remember , we can access Twitter API and access tweets even without this library. Tweepy makes the whole process simple and easy to understand and execute. Visit [HERE](https://pythonhosted.org/tweepy/index.html) for Tweepy's official documentation and a full list of offered features.
#
# Installing tweepy is easy, it can be pip installed as shown below:

# %%
# uncomment and pip install tweepy if you havent done so already
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\brian\anaconda3\lib\site-packages (3.6.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\brian\anaconda3\lib\site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\brian\anaconda3\lib\site-packages (from tweepy) (1.0.0)
# Requirement already satisfied: requests>=2.11.1 in c:\users\brian\anaconda3\lib\site-packages (from tweepy) (2.18.4)
# Requirement already satisfied: six>=1.10.0 in c:\users\brian\anaconda3\lib\site-packages (from tweepy) (1.11.0)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\users\brian\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (2.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\brian\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\brian\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\brian\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\brian\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2018.10.15)

# %% [markdown]
# We can now simply import import tweepy in the python working environment

# %%
# Import tweepy
import tweepy

import operator 
import json
from collections import Counter
import pandas as pd
from nltk import bigrams

# %% [markdown]
# So we are now good to move on with setting up tweepy with our user and access tokens.
#
# ### Using tweepy
# Tweepy supports accessing Twitter through OAuth. Twitter has stopped accepting Basic Authentication so OAuth is now the only way to use the Twitter API. In order to create the API object, however, we must first authenticate ourselves with our developer information.
# * Enter your credentials into access_token, access_token_secret, consumer_key, and consumer_secret below

# %%
# Set credential variables with appropriate string values
with open("") as f:
    d=json.load(f)
    consumer_key = d['consumer_key']
    consumer_secret = d['consumer_secret']
    access_token = d['access_token']
    access_token_secret = d['access_token_secret']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-98b50a7bb456> in <module>()
#       1 # Set credential variables with appropriate string values
# ----> 2 with open("") as f:
#       3     d=json.load(f)
#       4     consumer_key = d['consumer_key']
#       5     consumer_secret = d['consumer_secret']
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %% [markdown]
# ### Create the Authentication Object
#
# Our next step would be to create tweepy  OAuthHandler instance with our consumer key and secret and set access token and secret using `tweepy.set_access_token`. We can then create an API object with this information.
#
# We shall set it up as shown below:
#
# ```python
# # Create the tweepy authentication object with consumer key and secret
# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# # Setting your access token and secret
# auth.set_access_token(access_token, access_token_secret)
# # Creating the API object while passing in auth information
# my_first_api = tweepy.API(auth)
# ```

# %%
# Paste above code here with your credentials to create the Oauth Handler Instance and API object
# Create the tweepy authentication object with consumer key and secret
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
my_first_api = tweepy.API(auth)

# %% [markdown]
# If the above cell executed without any error.. congratulations. You can now start mining the Twitter API through `my_first_api` object.
#
# NOTE: If you have a web application and are using a callback URL that needs to be supplied dynamically, you would pass it in like shown below:
# ```python
# auth = tweepy.OAuthHandler(consumer_token, consumer_secret, callback_url)
# ```

# %% [markdown]
# ## Collecting Tweets From Own Timeline - `home_timeline()` method
# A detailed indsight into Tweepy's API object with supported methods to post, retrieve and select tweets can be found at [Tweepy's API Dcoumentation](https://pythonhosted.org/tweepy/api.html#api-reference). It is strongly recommended for you to visit the documentation and study all the relevant methods and arguments that they take.
#
# We can directly collect tweets from our home timeline by applying the method `api.home_timeline()`, which collects 20 most recent tweets by default (including retweeted tweets). To adjust the desired number of tweets (take 100 tweets for example),  we can pass in a parameter value as (count = 100).
#
# By default we get first 140 characters of a tweet. We can, however, optionally pass in an extra argument `tweet_mode='extended'` to get the full length of the tweet. This might be useful if you are interested in analyzing the full text of tweets rather than geographical locations, and hashtags etc. only.
#
# Perform the following
# * See how to get extended tweets [Here](https://github.com/sferik/twitter/issues/880). Use the API object to get tweets from your timeline ,collect 500 tweets.
# * Save the results into `my_timeline_tweets`.

# %%
# Store the tweets it in a variable called my_timeline_tweets

my_timeline_tweets = my_first_api.home_timeline(count = 500, tweet_mode='extended')

# %% [markdown]
# ### Tweet JSON
#
# All Twitter APIs that return Tweets provide that data encoded using JavaScript Object Notation (JSON). Here is a summary of information you may find in a typical Tweet JASON.
#
# * Each Tweet has an **author**, a **message**, a **unique ID**, a **timestamp** of when it was posted.
# * Some tweets contain **geo metadata** shared by the user.
# * Each User has a Twitter **name**, an **ID**, a **number of followers**, and most often an account **bio**.
# * With each Tweet we also get **"entity"** objects, which are arrays of common Tweet contents such as **hashtags**, **mentions**, **media**, and **links**.
# * If there are links, the JSON payload can also provide metadata such as the fully unwound **URL** and the webpage’s **title** and **description**.
#
# You may not need all this information for every experiment, but its a good idea to have a general understanding of what data we receive as the result of our API call.
#
# Here is what a Tweet JSON structure looks like:
#
# ---
#
# ```pythpn
# {
#   "created_at": "Thu Apr 06 15:24:15 +0000 2017",
#   "id_str": "850006245121695744",
#   "text": "1\/ Today we\u2019re sharing our vision for the future of the Twitter API platform!\nhttps:\/\/t.co\/XweGngmxlP",
#   "user": {
#     "id": 2244994945,
#     "name": "Twitter Dev",
#     "screen_name": "TwitterDev",
#     "location": "Internet",
#     "url": "https:\/\/dev.twitter.com\/",
#     "description": "Your official source for Twitter Platform news, updates & events. Need technical help? Visit https:\/\/twittercommunity.com\/ \u2328\ufe0f #TapIntoTwitter"
#   },
#   "place": {
#   },
#   "entities": {
#     "hashtags": [
#     ],
#     "urls": [
#       {
#         "url": "https:\/\/t.co\/XweGngmxlP",
#         "unwound": {
#           "url": "https:\/\/cards.twitter.com\/cards\/18ce53wgo4h\/3xo1c",
#           "title": "Building the Future of the Twitter API Platform"
#         }
#       }
#     ],
#     "user_mentions": [
#     ]
#   }
# }
#
#
#
# ```
#
# ---

# %% [markdown]
# ## Parsing Tweet JSON
#
# Let's try to print a single tweet to see what it looks like

# %%
# Unomment below to view contents of the tweet
my_timeline_tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x00000069BB8D2DD8>, _json={'created_at': 'Thu Nov 08 17:43:16 +0000 2018', 'id': 1060588577602433024, 'id_str': '1060588577602433024', 'full_text': 'RT @redsteeze: Same thing that happened to the Kavanaugh gang rape investigation https://t.co/bowon6O8E2', 'truncated': False, 'display_text_range': [0, 104], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'redsteeze', 'name': 'Stephen Miller', 'id': 393469195, 'id_str': '393469195', 'indices': [3, 13]}], 'urls': [{'url': 'https://t.co/bowon6O8E2', 'expanded_url': 'https://twitter.com/ForecasterEnten/status/1060579593105694720', 'display_url': 'twitter.com/ForecasterEnte…', 'indices': [81, 104]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 17995040, 'id_str': '17995040', 'name': 'Ben Shapiro', 'screen_name': 'benshapiro', 'location': 'California', 'description': 'EIC https://t.co/Jd8PhAEM3i, host of "The Ben Shapiro Show” podcast and syndicated radio, “The Ben Shapiro Election Special” on Fox News, NRO, Newsweek, NYT bestseller', 'url': 'https://t.co/hiB96sgNMH', 'entities': {'url': {'urls': [{'url': 'https://t.co/hiB96sgNMH', 'expanded_url': 'http://dailywire.com', 'display_url': 'dailywire.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/Jd8PhAEM3i', 'expanded_url': 'http://DailyWire.com', 'display_url': 'DailyWire.com', 'indices': [4, 27]}]}}, 'protected': False, 'followers_count': 1710457, 'friends_count': 197, 'listed_count': 9109, 'created_at': 'Tue Dec 09 16:40:22 +0000 2008', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 125834, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/746059589146140672/ursN3OVD_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/746059589146140672/ursN3OVD_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17995040/1471375462', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Nov 08 17:41:00 +0000 2018', 'id': 1060588008976596993, 'id_str': '1060588008976596993', 'full_text': 'Same thing that happened to the Kavanaugh gang rape investigation https://t.co/bowon6O8E2', 'truncated': False, 'display_text_range': [0, 65], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/bowon6O8E2', 'expanded_url': 'https://twitter.com/ForecasterEnten/status/1060579593105694720', 'display_url': 'twitter.com/ForecasterEnte…', 'indices': [66, 89]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 393469195, 'id_str': '393469195', 'name': 'Stephen Miller', 'screen_name': 'redsteeze', 'location': 'New York City of Brooklyn', 'description': 'Current commentary at FoxNewsDotCom Published The Wilderness (Now a Pod Bro podc ...

# %% [markdown]
# So the Tweet here is in the JSON format , which we can parse as dictionaries.
#
# We can iterate through collected tweets in `my_timeline_tweets` to access any of the properties of each tweet. Let's print the name and location of users with `.user.name`, `.user.locations` propoerties, and content of the each tweet using the `.text` property.
#
# **NOTE:** Use `.full_text` in case of using `tweet_mode='extended'` OR just `.text` if you havent passed in the extended argument.
#
# #### Iterate through `my_timeline_tweets` and print the usernames, location and text of the each collected tweet.

# %%
# Iterate through my_timeline_tweets and print the name, location and text for each tweet using k:v pairs addressing
for x in my_timeline_tweets:
    print (x.user.name)
    print (x.user.location)
    print (x.full_text)

# EXAMPLE OUTPUT
    
# Dr. Data&Science 🎃
# SFO | ATL | 🛫
# RT @RalstonReports: The turnout models are looking better for Democrats in Nevada as they boost their statewide lead a bit, but long way to…
# ----------------------------------------------------------------------------
# Data Science Central
# Seattle, WA
# [Cheat Sheet] Python Basics For Data Science https://t.co/fH07ZFF9zw
# ----------------------------------------------------------------------------
# Dr. Data&Science 🎃
# SFO | ATL | 🛫
# RT @Popehat: NYT:  Well, Okay, But Are People Mean To Trump?
# Everyone: Can you not
# NYT:  Jazz: What If Black People Got Involved In Jazz
# Ev…
# .
# .
# .
# .
# IBM Data Science
# San Francisco, CA
# Essential math for data science: A curated list including functions, variables, equations, graphs, statistics, linear algebra, calculus, discrete math, optimization, and operation research topics, whew. Check it out here: https://t.co/0JtcPuJ04N via @kdnuggets #datascience https://t.co/E2m2trORG9
# ----------------------------------------------------------------------------
# Data Science Central
# Los Angeles, CA
# The Mathematics of Machine Learning https://t.co/GUBZVT8NUj
# Out:
# Ben Shapiro
# California
# RT @redsteeze: Same thing that happened to the Kavanaugh gang rape investigation https://t.co/bowon6O8E2
# LeBron James
# Amongst La Familia!
# My thoughts and prayers are with the families who lost loved ones last night in Thousand Oaks, CA!!!! 🙏🏾🙏🏾🙏🏾💯 #LoveIsStrongerThanHate💪🏾
# Jon Favreau
# Los Angeles, CA
# RT @PodSaveAmerica: "Look at Beto O'Rourke, Stacey Abrams and Andrew Gillum, and the movement and people they've inspired, and then you tel…
# Tommy Vietor
# Los Angeles, CA
# RT @KSoltisAnderson: One more thing, and this is the real punch in the face for Republicans: Millennials are now into their mid-30s. And lo…
# Ben Shapiro
# California
# RT @realDailyWire: SALE: @BenShapiro 2024 Facts &gt; Feelings’ shirt on sale this week only!
#
# &lt;Air horn&gt; =&gt; https://t.co/HkqCaeJSPf https://t…
# Jon Favreau
# Los Angeles, CA
# RT @DKElections: Let's not lose sight of the fact that Democrats have flipped more House seats than they did in 2006 (and are on path to pi…
# Tommy Vietor
# Los Angeles, CA
# RT @creynoldsnc: This entire cycle @Schriock1 has said that we are going to deliver the majority with women.  I will confess that there wer…
# Tommy Vietor
# Los Angeles, CA
# RT @JesseCharlesLee: Nixon at the peak of Watergate, right in front of our eyes. https://t.co/kVWDV7ekkO https://t.co/teKwbKpNef
# The British History Podcast
# Portland, OR
# RT @chrislhayes: People aren’t objecting to firing Sessions! They’re objecting to making Whitaker acting AG, when you can easily fire Sessi…
# Ben Shapiro
# California
# RT @neontaster: Literally one minute apart. https://t.co/XmHkwQbxM1
# FiveThirtyEight
# New York, NY
# We'll be covering the world chess championship match, which begins Friday. https://t.co/TMyJe0ndRP
# Bill Simmons
# LA (via Boston)
# RT @ringer: Dear Vegas,
# @ryenarussillo, @bykevinclark, and @robertmays are coming your way for a special #DualThreat x #NFLShow recording a…
# Nate Silver
# New York
# Collins and Menendez MASSIVELY underperformed the fundamentals. (There's still an outside chance that Collins loses, BTW). Hunter to a slightly lesser extent. Scandals had a BIG effect on these races. https://t.co/DqdEoGSJBG
# NEW YORK KNICKS
# New York, NY
# A symbol of diverse cultures united across our City. #WearNewYork https://t.co/A7JEv0Q4XF
# XXL Magazine
# New York
# Cardi was in her bag on this one https://t.co/3M31vDbGcX
# Ben Shapiro
# California
# RT @redsteeze: "Actually kicking in the front doors of political pundits I don't like is good" is not a standard I'm guessing Yglesias want…
# Ben Shapiro
# California
# RT @jpodhoretz: Sounds like Nelson's lawyer is going to argue Florida should incept votes from properly executed ballots that have blank ar…
# Subway Status Delays
# New York, NY, USA
# #1train #2train and #3train have service change  #NYCsubway https://t.co/jh4U3Ctg8s
# Jon Favreau
# Los Angeles, CA
# RT @ZekeJMiller: ATLANTA (AP) — Stacey Abrams' campaign says it will continue fighting in Georgia governor's race; won't accept Kemp victor…
# NBA News Videos
#
# VIDEO: Derrick Rose Has NSFW Message for Lakers After Drilling 3-Pointer Over Lonzo Ball https://t.co/6bo4OYKNbn
# XXL Magazine
# New York
# DaBaby says he was shopping with his family in Walmart when he was approached by two men who pulled a gun on him. Shortly afterwards, a deadly shooting took place
# https://t.co/SVRSx0llMB
# Zach Braff
#
# RT @melissakchan: As someone who has had my press credentials denied by authoritarian China, I never thought I'd see this crap happen in th…
# FiveThirtyEight
# New York, NY
# Now that Sessions is actually leaving, the fate of Mueller’s probe looks a lot more uncertain. https://t.co/3fZdv0syUD
# NBA on TNT
# Atlanta, GA
# #HeadbandBron undefeated in LA 😂 https://t.co/hBqqmJJhjt
# Tommy Vietor
# Los Angeles, CA
# RT @brianschatz: The media got played. https://t.co/9nmMRNCqg3
# Tommy Vietor
# Los Angeles, CA
# RT @oneunderscore__: 😘👌
# https://t.co/81vKfECUAg
# Shaqtin' a Fool
# Atlanta, GA
# Here are your nominees for this week's #Shaqtin! 😂
#
# Vote for your favorite moment in the poll below. ⬇️
# Brooklyn Nets
# Brooklyn, NY
# Unveiled these a week ago.
#
# More City Edition news coming today... https://t.co/PQzS3UIeUa
# XXL Magazine
# New York
# RT @earlxsweat: WHO MADE THAT FUCKIN BEAT, U ASKED ?? @Kingsunnydey and the God Booliemane aka Darryl Johnson 😭😭😭⛽️⛽️⛽️
# XXL Magazine
# New York
# RT @earlxsweat: YEEAAAAOEOOEOEOE TO SAY IM EXCITED TO B GIVING YALL MUSIC IS BIG UNDERSTATEMENT. THIS YEAR BEEN THE ROUGHEST OF MY LIFE, BU…
# Jon Favreau
# Los Angeles, CA
# RT @noamscheiber: I agree with @NateSilver538 that an electoral-college strategy build around MI, WI, PA in 2020 is looking very viable aft…
# XXL Magazine
# New York
# RT @Lilpeep: COWYS2 comes out tomorrow.  Some local stores will be carrying the pink cassette and limited 2LP vinyl version, as well as the…
# XXL Magazine
# New York
# Very rare https://t.co/aC0zNonUYG
# Mike WiLL Made It 🐋🌊
# In Your Speakers
# RT @ShadyMadeMe6: @LiveLiteMarcel @MikeWiLLMadeIt @creedmovie When is the tracklist droppin?
# Mike WiLL Made It 🐋🌊
# In Your Speakers
# RT @antall_en: Omfg @MikeWiLLMadeIt I love you bruh!!!! This is legendary af! https://t.co/grEhlc9LWd
# Mike WiLL Made It 🐋🌊
# In Your Speakers
# RT @LiveLiteMarcel: @MikeWiLLMadeIt had a listening party for @creedmovie . Every song Slaps
# Metro Boomin
# Atlanta but St. Louis is home
# Thank God for the day!
# Jon Favreau
# Los Angeles, CA
# It’s true that many House Republicans will have one more election to cling to their gerrymandered seats before many new Democratic governors and legislatures get to redraw the maps. https://t.co/vO0x4ihVKq
# Jamal Crawford
# Seattle
# Another day, another opportunity..
# DeMarcus Cousins
# Mobile, AL
# MOOD 😂When’s the shirt dropping @PUMAHoops https://t.co/qJkEud66y5
# XXL Magazine
# New York
# .@smino’s ‘NØIR’ is out now with features from @dreezydreezy, @valee, @ravynlenae and more. What’s your favorite track so far? 🤔 https://t.co/3kyAllxv1e
# XXL Magazine
# New York
# 6ix9ine has some new music on the way https://t.co/Tc6lXufMzT
# XXL Magazine
# New York
# .@playboicarti has new music on the way.
#
# Listen to a preview of some tracks on his forthcoming project  https://t.co/yWQxLUbRSE
# Ben Shapiro
# California
# RT @EliLake: Mazel Tov to my friend @sohrabahmari on his new gig as op-ed editor of @nypost
# Jon Favreau
# Los Angeles, CA
# RT @danpfeiffer: I have worked on one recount with @marceelias and prepared for a couple more and he is not someone who uses hyperbole. He…
# Ben Shapiro
# California
# RT @redsteeze: Racist Democrats is why John James lost. https://t.co/JM6oAJhNiC
# Ben Shapiro
# California
# RT @DavidRutz: Domestic terrorism as a strategy, explained https://t.co/aENQe0YLRc
# Nate Silver
# New York
# Also follow Nathaniel Rakich (@baseballot) for more on the uncalled races beat. We're going to try to be a go-to source for you on this stuff.
# FiveThirtyEight
# New York, NY
# What is clear is the importance of Pennsylvania, Wisconsin and Michigan. https://t.co/EnAtHHzlWN
# Nate Silver
# New York
# On the other side, we're also moving NY-22 from "called D" to Likely D.  https://t.co/u4noA9uaEI
# Tommy Vietor
# Los Angeles, CA
# RT @ryanobles: BREAKING: First @AndrewGillum statement on possible #FLGov recount “It has become clear there are many more outstanding ball…
# XXL Magazine
# New York
# Dipset SZN is here
#
# https://t.co/1oZeH9a7jz
# NBA News Videos
#
# Celtics Unwillingness to Trade Terry Rozier Could Mean They’re Not Sold on Signing Kyrie Long Term https://t.co/2DtRYC1WvG
# Jon Favreau
# Los Angeles, CA
# RT @NPR: Christine Blasey Ford is still being harassed, her lawyers say. She's reportedly had to move four times. She's had to pay for a pr…
# Subway Status Delays
# New York, NY, USA
# #SIRtrain have delays [SIR] Tottenville-bound trains run on an adjusted schedule #NYC https://t.co/jh4U3Ctg8s
# Ben Shapiro
# California
# RT @NoahCRothman: It will be Christie. We can end the speculation right now. https://t.co/8FlGToh1co
# XXL Magazine
# New York
# 🆕 THE BREAK 🆕
#
# Compton rapper @RoddyRicch has a sound of his own, and his hit single "Die Young" shows a lot of promise. Learn more about him on @XXL's The Break https://t.co/WQ1x7mF49N
# #RingerNBA
# Los Angeles, CA
# RT @jkylemann: HEY YOU GUYS
#
# Here's part four (of four) of THE LEAP on the @ringer. A series where we examine the NBA's next generation of…
# Nate Silver
# New York
# Thread https://t.co/T14jUe9rlG
# NJ TRANSIT
# New Jersey
# ATTENTION NJT CUSTOMERS- The scheduled work on the Port Jervis line this weekend has been CANCELLED. Rail service will operate on a normal schedule. https://t.co/31GfLB8sZK https://t.co/cRA3rXAkk9
# XXL Magazine
# New York
# .@KendrickLamar's got a new song on the @MikeWiLLMadeIt-curated 'Creed 2' soundtrack
#
# https://t.co/xPBwRP8GYT
# FiveThirtyEight
# New York, NY
# What went down in the 2018 midterms --&gt; https://t.co/o6YE4kJc7o
# Jon Favreau
# Los Angeles, CA
# RT @jmartNYT: .⁦@clairecmc⁩ gets at an important part of rural realignment: nationalizing of media sources.
#
# She said she’d see Fox on TV…
# XXL Magazine
# New York
# What are your thoughts on this?
#
# https://t.co/rzZSxkIUXC
# Brooklyn Nets
# Brooklyn, NY
# It's still baseball weather in Arizona, so Joe Harris and Jarrett Allen went to the park and took some cuts at the @Cubs' spring training facility on their day off ☀️⚾ https://t.co/5aA1qs8IoK
# Russell Westbrook
# Oklahoma City
# Gave the Why Not Zer0.1 a little remix so check out The Chaos ... out now in 2 colors!! #whynot 🤷🏾‍♂️
# https://t.co/krnpMSOMTU https://t.co/GInjssmjsU
# #RingerNBA
# Los Angeles, CA
# Are the #Cavs’ City Edition unis 🌊 or 🗑? #ThisIsCLE
# 📷: @cavs https://t.co/OpomFy8XuN
# #RingerNBA
# Los Angeles, CA
# RT @JustinVerrier: In the Lakers’ 11 games: 9 have passed the crunch time threshold, 6 have been decided by 4 points or fewer, and 3 have h…
# Subway Status Delays
# New York, NY, USA
# #Btrain #Dtrain #Ftrain #Mtrain have delays Monday to Friday, until Nov 9Downtown [B] [Q] trains run at a slower speed in the area of 7 Av in Brooklyn #NYCsubway https://t.co/jh4U3Ctg8s
# New York Yankees
# Yankee Stadium
# A Stantonian Birthday. 🌋
#
# Buon compleanno, G! https://t.co/eeGTguAyDG
# Mike Duncan
# Paris, France
# I’ve already gone into preemptive exile. https://t.co/K3uYAVqtw7
# Dank Memes 💎💎💎
# 🔥FOR BUSINESS + PROMO DM ME🔥
# https://t.co/ONHEtwDpoI
# Timeless Sports
#
# (2002) @kobebryant 💭🏆 https://t.co/wUKS0rETtA
# XXL Magazine
# New York
# Feels like people are sleeping on how wild this actually is
#
# https://t.co/ZMTjsljzHv
# Mike Duncan
# Paris, France
# I am dunked on https://t.co/snVDs2mWiM
# Ben Shapiro
# California
# RT @HotlineJosh: Looking like the national House vote will be awfully similar to 2006.
#
# Dems won House vote by 6.4% in 2006.
# Just under tha…
# Mike Duncan
# Paris, France
# This is a fair point. https://t.co/HC4Dz31Gff
# Mike Duncan
# Paris, France
# I have always known I was going to wind up in an Austrian prison. https://t.co/4bjp9GxfUx
# Ben Shapiro
# California
# RT @RBPundit: Um. Do you even know what universal background checks are?
#
# Because this guy went through a background check. https://t.co/pN…
# #RingerNBA
# Los Angeles, CA
# Pick one: the Grizzlies' wrestling-inspired City Edition unis or the Sixers' 'Rocky' and #Creed2-inspired ones.
# #GrindCity #HereTheyCome https://t.co/R0DokWPFXk
# Ben Shapiro
# California
# RT @RabbiWolpe: Soundtrack of olam haba: The Sinatra bridge, low&amp;rising, in Riddle arranged “Old Man River” (&amp; the broken ‘and’ in Basie ‘e…
# NEW YORK KNICKS
# New York, NY
# About last night. https://t.co/KNWu12luDt
# Mike Duncan
# Paris, France
# One more. Just some light googling https://t.co/8OKYmulRjj
# Gordon Hayward
#
# I'll be signing autographs @NEPicture_com on Nov. 13 c/o @Fanatics. Come out and see @smart_MS3 &amp; me. #CUsRise #FanaticsExclusive https://t.co/5EygiMaQCr
# DWade
# I'm everywhere...
# Here it is #HEATNation - the official intro video for #ViceNights. I’m excited to be wearing this jersey during my #OneLastDance with the @MiamiHEAT. You can get your own #ViceNights jersey tonight at midnight at @AAarena or online. https://t.co/4jQYM9zIVi
# Mike Duncan
# Paris, France
# This one is from just the other night. https://t.co/TdpTItAyrg
# XXL Magazine
# New York
# Happy Birthday, @ERICB! 🎉
#
# https://t.co/TYQ9OnhTqm
# NJ TRANSIT
# New Jersey
# REMINDER-Due to Positive Train Control (PTC) track work and signal improvements, buses will replace Port Jervis Line trains between Harriman and Port Jervis stations tomorrow night, November 9 through Sunday, November 11. More info: https://t.co/RbK6MDOjcS https://t.co/YG0SgnR4Wr
# Mike Duncan
# Paris, France
# Oh yeah here’s one. Missouri I think. https://t.co/2X4zkRq8NN
# NBA News Videos
#
# Lance Stephenson GETS IN THE GYM Right After Lakers Defeat Timberwolves! https://t.co/lpyE78fR5K
# T.I.
# Atlanta, GA
# Never a dull moment... Da Homie
# @christuckerreal murk’d it last night!!! https://t.co/uqZ1J2fWdB
# XXL Magazine
# New York
# Creed's Scott Stapp says that he wasn't trying to commit suicide when T.I. found him and got him to the hospital in 2006
#
# https://t.co/SGCYlMNAaY
# Bill Simmons
# LA (via Boston)
# I enjoyed this https://t.co/Re9aPOlHEB
# Mike Duncan
# Paris, France
# Can’t organize in the street anymore? Is that true? I think I saw some recently, let’s see if I can dig up the pics... https://t.co/mfkavbvj05
# JR Smith
# @teamswish ig
# 🤷🏾‍♂️ https://t.co/UOhvCgNulA
# Ben Shapiro
# California
# RT @esaagar: Protestors did not merely gather and shout outside @TuckerCarlson's home. They broke his oak front door while his wife was hom…
# Ben Shapiro
# California
# RT @iowahawkblog: Tanned, relaxed, ready https://t.co/eF46aARQYg
# Subway Status Delays
# New York, NY, USA
# Delays reported on #Btrain #Dtrain #Ftrain #Mtrain Monday to Friday, until Nov 9Downtown [B] [Q] trains run at a slower speed in the area of 7 Av in Brooklyn #MTA https://t.co/jh4U3Ctg8s
# Trey Songz
#
# Lenny Williams - “Cause I love you” google that millennials please. I would love for you to appreciate it
# FiveThirtyEight
# New York, NY
# We’ll update this post on a semi-regular basis --&gt; https://t.co/mkjF6lOz3e
# Dirk Nowitzki
# Dallas
# Calling all superheroes. Today is the day. Join us for Cape Day to honor all of the brave patients at @Children’s Health. Check out https://t.co/FqRccn90W2 for more. #CapeDayNTX https://t.co/GyNSRGuQIZ
# XXL Magazine
# New York
# Before the fame
#
# https://t.co/SMDoVRrtRY
# Trey Songz
#
# If you don’t know the song, doesn’t mean the song wack... mean you wack.
# Enes Kanter
# New York, USA
# RT @MSGNetworks: That was a scary fall for @Enes_Kanter, but don't worry about him. He's just getting ready for his @WWE career. 😁 #Knicks…
# Enes Kanter
# New York, USA
# RT @mariohezonja: @Enes_Kanter @WWE Hadi kardeşim!!!!! ❤️🇭🇷 🇹🇷
# Kevin O'Connor
# Hollywood, Los Angeles
# The Celtics and Sixers are both feeling growing pains as they incorporate Hayward and Fultz into the mix. But it’s a necessity. On the challenges finding balance for both teams, from Monday on @ringer: https://t.co/l4pLyZHq6r
# Mike Duncan
# Paris, France
# Don’t tweet about Antifa and set your phone down for an hour.
# Ben Shapiro
# California
# This is my point. Correlation between state gun laws and mass shootings is non-existent. https://t.co/OjHE8871gz
# Bill Simmons
# LA (via Boston)
# We did a new Rewatchables podcast: ‘All the President’s Men’ w/ me, @ChrisRyan77 @SeanFennessey ... Get out your headphones, there’s more. Your lives are in danger.
#
# https://t.co/wkMv98cs4g
# Nate Silver
# New York
# The newly-elected D House members also strike me as being fairly ready for duty—there weren't the sort of accidental winners you sometimes see in wave elections. A lot of them are liable to be fairly tough incumbents, although the incumbency advantage is weaker than it once was.
# Ben Shapiro
# California
# RT @cjane87: If this is like when I finished my thesis they’ve got two cans of Monster and six packs of gum and let’s not lie, the last ten…
# FiveThirtyEight
# New York, NY
# He likes movies. He likes music. He likes to eat. He works out. He goes on dates.
#
# Just a normal guy.
#
# Just a normal guy who is ranked second in the world in chess.
#
# https://t.co/3f49HxymKN
# Nate Silver
# New York
# If Dems hold the House in 2020, it may get easier after that because the map will probably be less gerrymandered thereafter. I kind of wonder if we're entering an era where Congress will be split (D House, R Senate) a lot more often.
# Ben Shapiro
# California
# RT @RachaelBL: I cried when I watched @MiaBLove’s 2017 March for Life speech. So I was especially outraged by Trump’s caustic remarks about…
# Ben Shapiro
# California
# RT @BreakingNews: @AP Sheriff: Gunman is believed to have used a legally purchased .45 caliber handgun with an "extended magazine;" believe…
# Ben Shapiro
# California
# RT @michaelshermer: Another Dream Deferred. My @QuilletteM on how identity politics, intersectionality theory, and tribal divisiveness are…
# Nate Silver
# New York
# That popular vote margin is going to rise—I'm guessing to about 7%, maybe 7.5%—but Democrats did a really good job capitalizing on their opportunities. https://t.co/wAZEHslrc6
# XXL Magazine
# New York
# Boss moves only
#
# https://t.co/NND559cIV5
# NBA News Videos
#
# Kristine Leahy does a complete breakdown of the Lakers – Wolves game from her court-side seat https://t.co/JHjbj9gWDd
# Ben Shapiro
# California
# RT @JD_Tuccille: "the group broke his oak door and one person mentioned a pipe bomb, as heard on a security video." https://t.co/BIGF3PqjJG…
# Subway Status Delays
# New York, NY, USA
# #Atrain #Ctrain and #Etrain have delays  #MTA https://t.co/jh4U3Ctg8s
# Jon Favreau
# Los Angeles, CA
# RT @RaviMGupta: .@GinaOrtizJones campaign needs help on the ground. If you or someone you know can spring into action in the district, emai…
# Brooklyn Nets
# Brooklyn, NY
# RT @LongIslandNets: GAME DAY 🏀
# 📍 @nycblive
# ⏰ 7:00pm
# 📺 @yesnetwork &amp; ESPN+
# 📻 @wrhusports
# 🎙 @K_Dexter, @randyfoye &amp; @G_Antoniello
# 🎟 https:/…
# Ludacris
# Atlanta, GA
# Waking up feeling like...... https://t.co/GxKOEejsGU
# XXL Magazine
# New York
# Abel's got a new LP on the way
#
# https://t.co/1WWST1DGnr
# NBA News Videos
#
# ‘Long season, man’: Why Boston isn’t sweating its slow start https://t.co/PyOBBUuc0T
# XXL Magazine
# New York
# ⬇️ Today in Hip-Hop ⬇️
#
# @Eminem ends up having four singles in the Billboard Hot 100 chart's top 20
#
# https://t.co/aAFBHmJndI
# Subway Status Delays
# New York, NY, USA
# Planned work reported on #Ltrain [L] Service runs every 12 minutes between Myrtle-Wyckoff Avs and Rockaway Pkwy in Brooklyn #MTA https://t.co/jh4U3Ctg8s
# Lil Wayne WEEZY F
# Mars
# Backwoods &amp; Big Shots.. YM.. Vise Versa 🤙🏾 https://t.co/AeeYZXDKK4
# XXL Magazine
# New York
# Lil Peep and XXXTentacion's posthumous song "Falling Down" has officially been certified gold
#
# https://t.co/eNVTcrc7Nu
# XXL Magazine
# New York
# Happy Birthday @TechN9ne! 🎉 What's his best song ever?
#
# https://t.co/FgNJ0n3ATN
# XXL Magazine
# New York
# RT @Ruleyork: You 50 trolls are trying waaay to hard hope y’all getting a check and not just a ✔️lmao... Anyway for the ones on the short b…
# Nate Silver
# New York
# We're also moving GA-7—another one where the networks differ—from "called R" to Likely R. The Dem trails by 900 votes here but there's 20K absentee votes still left to be counted. https://t.co/2p5vDKarsP
# Brian Windhorst
# Arenas, studios, airplanes
# RT @andrewthehan: [🎧] Running diary pod from @WindhorstESPN as he starts at shootaround with @TajGibson22 @ATolliver44 and ends the day fro…
# NBA News Videos
#
# [Canton Rep] - NBA G League Preview: Canton Charge at Maine Red Claws https://t.co/oHfYp9TEVp
# Jack Seigel
# St Louis, MO
# I will give all my organs to RBG.  Just lemme know what she needs.
# DWade
# I'm everywhere...
# Flame thrower! https://t.co/XgzMmxrjFk
# Jon Favreau
# Los Angeles, CA
# RT @LEBassett: Please- nobody ask @PressSec another question until she is forced to address the doctored video she fed the public.
# Ben Shapiro
# California
# The Brady Center says California has the nation’s strongest gun laws. https://t.co/ZUZBPwragQ
# XXL Magazine
# New York
# Weezy was spazzing on this
#
# https://t.co/IOrF3p3re2
# Ben Shapiro
# California
# RT @guypbenson: “The protesters had blocked off both ends of his street and carried signs that listed his home address.” They also cracked…
# Ben Shapiro
# California
# RT @realDailyWire: THE @BENSHAPIRO SHOW: SUNDAY SPECIAL! @JohnStossel joins Ben to discuss Libertarianism, drug decriminalization, the Amer…
# Mike Duncan
# Paris, France
# This is like asking “what would you recommend instead of sticking my finger in a light socket?” There are many answers. All of them start with not sticking your finger in light sockets anymore. https://t.co/V1ivT3H2KX
# Ben Shapiro
# California
# RT @brianstelter: Carlson's wife "locked herself in the pantry and called 911." @DCPoliceDept responded to the scene. Police will be paying…
# Mike Duncan
# Paris, France
# I am antifascist. I also believe the Antifa kids are so confoundingly stupid that they may as well be a false flag operation. Not saying they ARE a false flag operation. Just that they may as well be for all the good they do.
# Ben Shapiro
# California
# RT @SethAMandel: All Trump had to do was say “Dear diary” and Acosta would’ve disintegrated on the spot and he’d be president forever
# Ben Shapiro
# California
# RT @LahavHarkov: Her mourning after the Pittsburgh tragedy was clearly just a brief detour from her regularly-scheduled antisemitism.
#
# As…
# Brooklyn Nets
# Brooklyn, NY
# Nets fans! We have 10 exclusive fan experiences at @barclayscenter designed to give you and your family memories that will last a lifetime. Get your package today before we come back home next week!
#
# 👉 https://t.co/3NDOrPxmWe https://t.co/5rA9HthFXb
# Tommy Vietor
# Los Angeles, CA
# RT @abc7greg: Absolutely heartbreaking interview from witness with @ABC7Jory at scene of reported mass shooting at #Borderline in #Thousand…
# XXL Magazine
# New York
# J. Cole has been in his bag all 2018
#
# https://t.co/BVfxTkyPm0
# Ben Shapiro
# California
# RT @BenShapQuotes: https://t.co/KxxI2Ifi5P
# Subway Status Delays
# New York, NY, USA
# #7train have planned work Nov 7 - 9, Wed to Fri, 10:15 AM to 3 PMNov 12 - 16, Mon to Fri, 10:15 AM to 3 PMFlushing-bound [7] trains skip 33, 40, 46, 52 and 69 Sts in Queens #NYCsubway https://t.co/jh4U3Ctg8s
# Ben Shapiro
# California
# RT @SeanTrende: You can sort of sort these districts that flipped into a few buckets (obvs things have changed since I sketched this out la…
# FiveThirtyEight
# New York, NY
# Renewed strength in the Upper Midwest would be great news for Democrats. https://t.co/q7fYvWXiI3
# Ben Shapiro
# California
# RT @marklevinshow: Horror https://t.co/3hwvVhv7EE
# Ben Shapiro
# California
# RT @jpodhoretz: @samstein his resume is that he was chief of staff for Ashcroft and then US Attorney in Iowa. That's actually his resume.
# Ben Shapiro
# California
# RT @marklevinshow: Another that the media ignore https://t.co/YdsnLLDzqj
# Ben Shapiro
# California
# RT @WillieGeist: This is Ventura County Sherrif’s Sgt. Ron Helus, killed as he responded to stop the mass shooting at Borderline Bar and Gr…
# Ben Shapiro
# California
# RT @realDailyWire: So It Begins | The @BenShapiro Show Ep. 654
#
# WATCH: https://t.co/LozIlT3p6J https://t.co/71vyupmz5l
# XXL Magazine
# New York
# 6ix9ine's manager faces assault charges after turning himself in for his alleged role in a New York shooting that led to one of Tekashi's associates being shot
#
# https://t.co/r6LIuCQzR6
# Ben Shapiro
# California
# RT @laurennnjoness2: my history professor is tired of our shit https://t.co/iYqe0N2tOc
# Jon Favreau
# Los Angeles, CA
# RT @MaxRose4NY: You might be seeing a lot of hot takes about how we won. Here’s the truth - it wasn’t that complicated:
#
# ✅ Knock on every…
# Ben Shapiro
# California
# RT @SonnyBunch: I’m sad this is no longer what Jim Acosta’s profile looks like because it’s kind of perfect. https://t.co/wh4JqU0K3k
# Ben Shapiro
# California
# RT @charlescwcooke: Wishing a speedy recovery to Justice Ginsburg. Broken ribs are excruciating.
# Ben Shapiro
# California
# RT @EdMorrissey: Yikes. https://t.co/bCsgkgxRfP
# Nate Silver
# New York
# Among the uncalled Senate races, we have Arizona as Lean R, Florida as Likely R, and the Mississippi special election also as Likely R.
#
# Republicans will net 3 seats from Democrats if they win all 3.
# Subway Status Delays
# New York, NY, USA
# Planned work reported on #Ntrain #Qtrain #Rtrain #Wtrain [W] Service is replaced by [N] trains between 57 St-7 Av in Manhattan and Ditmars Blvd in Queens[W] Trains run every 20 minutes in Manhattan #MTA https://t.co/jh4U3Ctg8s
# XXL Magazine
# New York
# Blac Youngsta is hilarious
#
# https://t.co/dLzLvchyhd
# Nate Silver
# New York
# NY-27 (Chris Collins) is another one where there's some disagreement on whether the race can be called. After looking at it, we're moving it to Likely R. The margin is ~2700 with ~10K absentees to be counted. Highly likely Collins wins but not 100% safe. https://t.co/bOeEXtYdMd
# FiveThirtyEight
# New York, NY
# RT @ollie: the world chess championship starts tomorrow. here’s the american who could win it: https://t.co/Ctk4UF6zc0
# FiveThirtyEight
# New York, NY
# Wells Fargo admitted that 545 of its customers lost their homes thanks to “an internal underwriting error” in its software. https://t.co/8OsYxfEI2T
# NBA News Videos
#
# Allonzo Trier Full Highlights 2018.11.07 Knicks vs Hawks – 16 Pts, NASTY Crossover! | FreeDawkins https://t.co/PbBNIPB1fi
# XXL Magazine
# New York
# This has to be a first, right?
#
# https://t.co/LGAdHeBqhG
# NBA News Videos
#
# Tyson Chandler On Lakers Reception When He Checked In For First Time https://t.co/0gCmqakD0g
# Nate Silver
# New York
# Missed one: We're also rating TX-23, which has been called by some networks and not others, as Likely R.
#
# Most likely, though, it will be the five in the middle, CA-10, CA-39, CA-45, ME-2 and NJ-3, that determine where we end up on the scale from D+35 to D+40.
# Nate Silver
# New York
# Here's how we rate the remaining uncalled races. In several of these, there are concessions but no official @ABC or AP call:
# Solid D (&gt;=95%)—CA-48, CA-49, WA-8
# Likely D (~85%)—NM-2, UT-4
# Lean D (~65%)—CA-10, CA-39
# Tossup (~50%)—CA-45, ME-2, NJ-3
# Lean R
# Likely R
# Solid R—MN-1, NC-9
# NBA News Videos
#
# Tim Hardaway Jr Full Highlights 2018.11.07 Knicks vs Hawks – 34 Pts! | FreeDawkins https://t.co/MkH7aGVcVN
# #RingerNBA
# Los Angeles, CA
# These aren’t your slightly older sibling’s Lakers. #LakeShow https://t.co/otAnpkxkX5
# Nate Silver
# New York
# Democrats won The Ossoff Seat. https://t.co/MrHrWGGu03
# XXL Magazine
# New York
# 6ix9ine always has time
#
# https://t.co/ToBjF90FCP
# Subway Status Delays
# New York, NY, USA
# Planned work on #SIRtrain [SIR] Tottenville-bound trains run on an adjusted schedule #MTA https://t.co/jh4U3Ctg8s
# Nate Silver
# New York
# The Sunbelt Strategy may be tempting to Dems, especially if Texas is now more competitive. But the Northern Path—Wisconsin, Michigan, Pennsylvania—sure looks a lot easier. What you really don't want it to get stuck in between the two, which is sort of what happened to Clinton.
# Nate Silver
# New York
# Basically, a Democrat hoping to win the WH can undertake one of 2 strategies:
# 1) Northern Path—Flip WI, MI &amp; PA back to blue. Hold MN.
# 2) Sunbelt Strategy—Lose all the above states, but win FL and any of NC, AZ, TX(!), GA.
# Mark Cuban
#
# Why I Don't Wear a Suit and Can't Figure Out Why Anyone Does ! https://t.co/0FcmH6ZSOC via @wordpressdotcom
# Nate Silver
# New York
# Of course, Tuesday was a very blue night. But if you shift every state toward Republicans by 6 points, which roughly reflects what you'd get in a neutral political environment, here's what the map looks like. This looks like a pretty fair fight for the Electoral College. https://t.co/HKe1z66C22
# XXL Magazine
# New York
# Travis really wanted people to vote
#
# https://t.co/qSUq76Lnvq
# XXL Magazine
# New York
# Welcome to Atlanta https://t.co/EYm2tGsQEi
# FiveThirtyEight
# New York, NY
# RT @maggiekb1: Remember kids: matching names between databases is not easy (if you care about accuracy) https://t.co/lkq35xXNfj
# NBA News Videos
#
# Trae Young vs Frank Ntilikina PG Duel 2018.11.07 – Trae With 15-8, CLAMPED By Ntilikina! https://t.co/g9ctbru7i3
# Nate Silver
# New York
# Democrats did very well in Michigan, Wisconsin and Pennsylvania, which are basically the tipping-point states right now. I posted this map last night, but here's who won each state in the popular vote for the House in each state. Dark blue / dark red = won by at least 5 points. https://t.co/Q7PLB6d4Ob

# %% [markdown]
# Thats is great. We are getting some meaningful information indeed.
#
# #### Before we proceed ....
# *We are using a test account and following a number of AI, Data science and Tech groups/companies to progress through the lab. Based on your own preferences , your results may be different than what you see here. You are encouraged to ask some meaningful questions and parse the JSON around how YOU use twitter.**

# %% [markdown]
# ###  Store the Tweets JSON File

# %% [markdown]
# It is always a good idea to store the tweets as a JSON file as executing above cells will bring in new tweets and will keep re-writing the object. This can have negative impacts on your analysis (unless you are analyzing live streams).
# * Store the `my_timeline_tweets` JSON object in `tweets.json` file.

# %%
# Store my_timeline_tweets as a JSON file
import json
dicts = []
for x in my_timeline_tweets:
    dicts.append(x._json)

with open('tweets.json', 'w') as file:
    file.write(json.dumps(dicts, indent=4))

# %% [markdown]
# #### Open `tweets.json` and inspect its contents in relation to the JSON object shown below.

# %% [markdown]
# ## NATURAL LANGUAGE PROCESSING
#
# Twitter data is of the most favorite dataset for data scientists and Natural Language Processing (NLP) researchers. Besides its magnanimous size, Twitter data has other unique qualities as well: it comprises of real-life conversations, limited word length, rich variety, and real-time data stream. Advanced analytics on Twitter data needs one to go beyond the words and parse sentences into syntactic representations to develop a better contextual understanding of the tweet content. We shall cover more of that in our sections dedicated to NLP.
#
# ![](https://static1.squarespace.com/static/5552e2d6e4b098f713cf2613/t/56e3930327d4bdfdac7c34a9/1457754894624/?format=750w)
#
# Here we shall look at some basic techniques that you might want to use for cleaning text data and look for important words, mentions, URLs  or hashtags etc.
#
# #### Good old word count ..
#
# A very fundamental NLP skill, without using any complicated algorithms is to count the occurrences of words/terms (known as **TERM FREQUENCIES** of TFs). With this, we can observe what are the terms most commonly used in the data set.
#
# ### Tokenization
#
# Tokenization is an NLP specific term which concerns with breaking down a text document (like a tweet) into its tokens (words/terms). Below we have a simple custom tokenization routine that will parse each tweet and split it into words/terms to capture Twitter-specific aspects of the text, such as **#hashtags**, **@mentions**, **emoticons** and **URLs**. In order to tokenize , you simply need to pass each tweet to the `preprocess_tweet()` function below and it will be split into its constituent terms.

# %%
# A SIMPLE TOKENZIER IMPLEMENTAION 

# Import Regular Expressions
import re

# Identify some basic emoticon elements (face, nose, mouth )- you are encouraged to add more for other emoticons
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""

# Identify Twitter specific elements in a tweet
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess_tweet(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %% [markdown]
# The code above uses a lot of regular expressions to search for twitter specific terms. Let's pass in a sample tweet to `preprocess_tweet` function and inspect the output.

# %%
example_tweet = 'ExampleTweet @datascienceguy: You are an NLP superstar :D http://example.com #NLP #datascience :P'
print(preprocess_tweet(example_tweet))
# Out:
# ['ExampleTweet', '@datascienceguy', ':', 'You', 'are', 'an', 'NLP', 'superstar', ':D', 'http://example.com', '#NLP', '#datascience', ':P']

# %% [markdown]
# So here you can see that each word, URL, emoticon has been sucessfully identified as a **Term**. Now we can do some basic analysis with these terms.

# %% [markdown]
# ### Count Term Frequencies
#
# As a first step, we can simply count the total number of occurances of teach term. Keep in mind that at this stage , we are also counting punctuation marks and common words like "the" "of" "for etc.
#
# Perform following tasks.
# * Load the JSON file `tweets.json` into a new variable called `data`.
# * In order to keep track of the frequencies while we are processing the tweets, we can use `collections.Counter()`  from the `Counter` library, which behaves is a dictionary (term: count) with some useful methods like `update()` and `most_common()`. [Here is a link to official doc. for consultation](https://docs.python.org/2/library/collections.html).
# * Iterate through the list of tweets update the term counter using `.update()` method for all terms after each iteration.
# * Count all the terms and list top ten most common terms

# %%
# Count all terms frequency from the saved JSON file
with open('tweets.json', encoding='utf-8') as json_file:  
    data = json.load(json_file)
    count_all = Counter()
    for x in data:
        terms_all = [term for term in preprocess_tweet(x['full_text'])]
        count_all.update(terms_all)
print(count_all.most_common(10))
# [(':', 142), ('.', 94), (',', 92), ('RT', 91), ('the', 81), ('to', 65), 
# ('…', 65), ('of', 65), ('and', 64), ('a', 58)]
# Out:
# [('.', 186), ('the', 105), (':', 96), (',', 90), ('RT', 70), ('to', 62), ('and', 56), ('a', 56), ('in', 54), ('’', 48)]

# %% [markdown]
# Right so in above output , we see that our punctuation marks and common terms like "the" and "of" etc. are being shown as top terms. The next step is to remove these words to focus on more IMPORTANT words. this step is called the "Stop-word Removal".

# %% [markdown]
# ### Stop Word Removal
#
# Every language has words that are very common. While their use in the language is very important, they do not carry any clear meaning on their own like conjunctions,  adverbs, etc. In the language of NLP , these are referred to as **Stop-words**.
# Stop-word removal is one important step that should be considered during the pre-processing stages. One can build a custom list of stop-words, or use available lists (e.g. [NLTK](https://www.nltk.org/) provides a simple list for English stop-words). You can search Internet for domain specific stop-words as well as some words may carry a deeper meaning in one domain while could be meaningless in another. (Try thinking of a few examples).
#
# Given the nature of our data and our tokenization, we should also be careful with all the punctuation marks and with terms like RT (used for re-tweets), via (used to mention the original author of an article or a re-tweet), ... (used for ongoing tweet) etc. Below is a stop word list that we build from nltk + punctuation + some twitter specific stop words. Your are encouraged to add more to it.

# %%
# Create a stop word list from nltk stopwords, punctuation marks and some twitter specific stop terms
from nltk.corpus import stopwords
import string
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'RT',  'via', 'The', 'the', '…', '¡']
print(stop)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79             except LookupError as e:
# ---> 80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      81                 except LookupError: raise e
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     674     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 675     raise LookupError(resource_not_found)
#     676
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Searched in:
#     - 'C:\\Users\\Brian/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'C:\\Users\\Brian\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\Brian\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\Brian\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\Brian\\AppData\\Roaming\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-24-105497d699a1> in <module>()
#       3 import string
#       4 punctuation = list(string.punctuation)
# ----> 5 stop = stopwords.words('english') + punctuation + ['rt', 'RT',  'via', 'The', 'the', '…', '¡']
#       6 print(stop)
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     114             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     115
# --> 116         self.__load()
#     117         # This looks circular, but its not, since __load() changes our
#     118         # __class__ to something new:
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
# ---> 81                 except LookupError: raise e
#      82
#      83         # Load the corpus.
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      76         else:
#      77             try:
# ---> 78                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     673     sep = '*' * 70
#     674     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 675     raise LookupError(resource_not_found)
#     676
#     677
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Searched in:
#     - 'C:\\Users\\Brian/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'C:\\Users\\Brian\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\Brian\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\Brian\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\Brian\\AppData\\Roaming\\nltk_data'
# **********************************************************************

# %% [markdown]
# Now we can simply use this list to clean up our tweets. Perform following tasks
# * Clear count_all to start a new counter
# * Change the routine above to collect tweets while filtering with above stop word list.
# * Use list comprehension to only include terms NOT found in the stop-word list
# * Print the top ten most common terms.

# %%
# Calculate term frequencies

count_all.clear()    

for tweet in data:
    terms_minus_stop = [term for term in preprocess_tweet(tweet['full_text']) if term not in stop]
    count_all.update(terms_minus_stop)
print(count_all.most_common(10))

    
# [('Vote', 35), ('#ODSCWest', 29), ('Data', 26), ('#ODSC', 21), ('#DataScience', 18), 
# ('’', 16), ('AI', 16), ('#AI', 14), ('@ODSC', 13), ('data', 12)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-14a8e624a908> in <module>()
#       4
#       5 for tweet in data:
# ----> 6     terms_minus_stop = [term for term in preprocess_tweet(tweet['full_text']) if term not in stop]
#       7     count_all.update(terms_minus_stop)
#       8 print(count_all.most_common(10))
#
# <ipython-input-27-14a8e624a908> in <listcomp>(.0)
#       4
#       5 for tweet in data:
# ----> 6     terms_minus_stop = [term for term in preprocess_tweet(tweet['full_text']) if term not in stop]
#       7     count_all.update(terms_minus_stop)
#       8 print(count_all.most_common(10))
#
# NameError: name 'stop' is not defined

# %% [markdown]
# So this looks much better, still not perfect though. Remember this is an iterative process and you would want to refine your stop word list. Here we see some useful terms like commonly mentioned hashtags etc. with lots of unwanted terms that xcould be included as stop words. Do some survey on other stop-word lists available online and include them with you own criteria.

# %% [markdown]
# ## More Term Filtering
#
# Besides stop-word removal, we can further customize the list of terms we are interested in.
#
# ### Calculate Document  Frequency
#
# > The number of documents in the collection that contain a term t.
#
# We can also calculate document frequency which shows us the number of documents (tweets) that show a specific term. For this we can make small tweaks to the code we used to calculate all terms frequencies for all document. Here we shall count every term only once in every document and see how many documents contain a specific term. For this you need to clear the counter, and perform following tasks for every tweet.
#
# * Calculate frequencies for all terms while filtering out the stop words
# * Make a set of unique terms (counted only once) for each tweet
# * Update the counter
#
# * Show the top 20 terms from the counter

# %%
# Calculate document frequencies

count_all.clear()    
for tweet in data: 
    terms_minus_stop = [term for term in preprocess_tweet(tweet['full_text']) if term not in stop]
    terms_single = set(terms_minus_stop)    
    count_all.update(terms_single)
terms_single = set(terms_all)
print(count_all.most_common(20))



# [('#ODSCWest', 29), ('Data', 24), ('#ODSC', 21), ('#DataScience', 18), ('’', 14), 
# ('AI', 14), ('#AI', 14), ('@ODSC', 13), ('data', 12), ('Science', 11), ('A', 11), ('2018', 11), 
# ('West', 11), ('3', 9), ('amp', 9), ('Join', 8), ('Nov', 8), ('How', 8), ('#bordercollie', 8), ('Python', 7)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-250ded00adb5> in <module>()
#       3 count_all.clear()
#       4 for tweet in data:
# ----> 5     terms_minus_stop = [term for term in preprocess_tweet(tweet['full_text']) if term not in stop]
#       6     terms_single = set(terms_minus_stop)
#       7     count_all.update(terms_single)
#
# <ipython-input-28-250ded00adb5> in <listcomp>(.0)
#       3 count_all.clear()
#       4 for tweet in data:
# ----> 5     terms_minus_stop = [term for term in preprocess_tweet(tweet['full_text']) if term not in stop]
#       6     terms_single = set(terms_minus_stop)
#       7     count_all.update(terms_single)
#
# NameError: name 'stop' is not defined

# %% [markdown]
# Do you see any improvements in results ? You may need to work more on the stop word list and maybe filter out the numerical terms like dates and other numbers. You could also filter out terms with length less than a set threshold e.g. only include terms that carry 4 or more characters. Like we saw earlier, it is an iterative process and we may have to revisit our parsing code a few times to get more meaningful answers.
#
# ### Calculate Hashtag Frequencies
#
# A Hashtag in a tweet is just another term , identified by a hash (#) sign. Let's iterate through our corpus of tweets again collecting all terms that are hashtags i.e. start with a #. Perform following tasks for each tweet:
# * Reset the counter
# * Collect the terms starting with # sign
# * Update the counter
# * List and visualize top 20 hashtags as bar charts and label properly

# %%
# Calculte top 20 hashtags

# Plot top 20 hashtags
count_all.clear()    

for tweet in data:
    terms_hash = [term for term in preprocess_tweet(tweet['full_text']) if term.startswith('#')]
    count_all.update(terms_hash)
print(count_all.most_common(20))
top20 = count_all.most_common(20)


# [('#ODSCWest', 29), ('#ODSC', 21), ('#DataScience', 18), ('#AI', 14), ('#bordercollie', 8), 
# ('#', 6), ('#abdsc', 4), ('#BigData', 4), ('#MachineLearning', 4), ('#datascience', 4), 
# ('#BorderCollie', 4), ('#DeepLearning', 2), ('#Python', 2), ('#puppy', 2), ('#dogs', 2), 
#('#dogsoftwitter', 2), ('#collie', 2), ('#earlyvote', 2), ('#TeamAbrams', 1), ('#GAGov', 1)]
# Out:
# [('#MTA', 5), ('#NYCsubway', 3), ('#SIRtrain', 2), ('#Btrain', 2), ('#Dtrain', 2), ('#Ftrain', 2), ('#Mtrain', 2), ('#ViceNights', 2), ('#LoveIsStrongerThanHate', 1), ('#DualThreat', 1), ('#NFLShow', 1), ('#WearNewYork', 1), ('#1train', 1), ('#2train', 1), ('#3train', 1), ('#HeadbandBron', 1), ('#Shaqtin', 1), ('#FLGov', 1), ('#NYC', 1), ('#whynot', 1)]

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
from pylab import rcParams
rcParams['figure.figsize'] =15, 5
plt.bar(range(len(top20)), [val[1] for val in top20], align='center')
plt.xticks(range(len(top20)), [val[0] for val in top20])
plt.xticks(rotation=70)
plt.title('Top 20 Hashtags')
plt.xlabel('Hashtags')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Calculate Bi-gram Frequencies
#
# While the frequent terms post cleaning, stop removal etc. represent a clear topic, simple term frequencies don’t give us a deeper explanation of what the text is about. To put things in context, let’s consider sequences of two terms combined (a.k.a. bigrams).
#
# > **A bigram is a sequence of two adjacent elements from a string of tokens, which are typically letters, syllables, or words. A bigram is an n-gram for n=2. The frequency distribution of every bigram in a string is commonly used for simple statistical analysis of text in many applications, including in computational linguistics, cryptography, speech recognition, and so on.**(wiki)
#
# We can import bigrams function from nltk library to automatically create bigrams from a given sequence of text. Here is a quick demo:

# %%
from nltk import bigrams 

text = 'This is a very simple sentence'
terms = [term for term in preprocess_tweet(text)]
terms_bigram = bigrams(terms)
list(terms_bigram)
# Out:
# [('This', 'is'),
#  ('is', 'a'),
#  ('a', 'very'),
#  ('very', 'simple'),
#  ('simple', 'sentence')]

# %% [markdown]
# The combination of two words may help get the deeper understanding of the tweet. You could also calculate trigrams or even higher , but it might get computationally expensive.
#
# You are required to calculate the frequencies of bigrams in the collected tweets, and find the most frequent combination of two adjacent elements. Perform following tasks:
#
# * Clear the counter
# * Collect all the terms excluding stop words, hashtags and mentions
# * Calculte the bigrams for each tweet and update counter with frequencies
# * Display and top 20 bigrams

# %%
# Show the frequency of top 20 bigrams in the corpus
from nltk import bigrams 

text = 'This is a very simple sentence'
terms = [term for term in preprocess_tweet(text)]
terms_bigram = bigrams(terms)
list(terms_bigram)


# [(('Vote', 'Vote'), 33), (('Data', 'Science'), 11), (('San', 'Francisco'), 7), 
# (('West', '2018'), 7), (('Oct', '31'), 5), (('31', 'Nov'), 5), (('Nov', '3'), 5), 
# (('Don', '’'), 4), (('Francisco', 'Oct'), 4), (('Big', 'Data'), 4), (('machine', 'learning'), 3), 
# (('data', 'scientists'), 3), (('data', 'science'), 3), (('Machine', 'Learning'), 3), 
# (('Deep', 'Learning'), 3), (('Data', 'Scientist'), 3), (('LIVESTREAM', 'Pass'), 3), 
# (('I', '’'), 3), (('\u2066', '\u2069'), 3), (('Cheat', 'Sheet'), 2)]
# Out:
# [('This', 'is'),
#  ('is', 'a'),
#  ('a', 'very'),
#  ('very', 'simple'),
#  ('simple', 'sentence')]

# %% [markdown]
# So we start to see something a bit more meaningful. For this case, we see more meaningul combinations of words which clearly indicate themes or recurring topics within tweets. A bit more effort can really get us results that can be easily analyzed to get some real insights.

# %% [markdown]
# ## Collecting Tweets From A User's Timeline - `user_timeline()` method
#
#
# For some analyses, you may be interested in collecting tweets from someone else's timeline. We can use `user_timeline()` method to achieve this while passing `id=name` parameter to identify the user. Let's collect last 100 tweets from "FlatironSchool" and visualize top 10 hashtags and mentions. Apart from the new method `user_timeline()`, everything else will remain the same as above. Perform following tasks:
#
# * Collect last 200 tweets from "FlatironSchool"
# * Calculate top 10 hashtags and mentions as terms from collected tweets
# * Visualize results as bargraphs in both cases

# %%
# Calculate and Visulize top 10 hashtags in last 200 tweets from FlatironSchool's Timeline
name = "FlatironSchool"
# Number of tweets to pull
tweetCount = 200
results = my_first_api.user_timeline(id=name, count=tweetCount, tweet_mode='extended')
count_all.clear()
for tweet in results:
        terms_hash = [term for term in preprocess_tweet(tweet.full_text) if term.startswith('#')]
        count_all.update(terms_hash)

top10 = count_all.most_common(10)

import matplotlib.pyplot as plt
plt.style.use('seaborn')
from pylab import rcParams
rcParams['figure.figsize'] =15, 5
plt.bar(range(len(top10)), [val[1] for val in top10], align='center')
plt.xticks(range(len(top10)), [val[0] for val in top10])
plt.xticks(rotation=70)
plt.title('Top 10 Hashtags from FlatironSchool Timeline')
plt.xlabel('Hashtags')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Collecting Tweets Using a Keyword -  `.search()` method
#
# Let’s look at one last use case i.e. getting the most recent tweets that contain a specific keyword. This can be extremely useful if you want to monitor specifically mentioned topics in the Twitter world, or even to see how your business is getting mentioned. We shall use Twitter standard serach API whith `q=query` parameter to pass our search query.
#
# Let’s say we want to see how FlatironSchool is being been mentioned on Twitter. We would like to see which Twitter  users are being mentioned in conjunction with FlatironSchool. Remember maxiumum number of tweets you can mine is 180 per 15 minutes window.
#
# Perform following tasks
# * Clear the counter
# * Collect 200 tweets that mention Flatiron School using `.search()` method. (Use `language=en` to collect english tweets only)
# * Collect the top 30 @mentions from the all tweets that mention FlatironSchool.
# * Visualize the results as a wordcloud

# %%
# The search term you want to find
query = "FlatironSchool"
# Language code (follows ISO 639-1 standards)
language = "en"
tweetCount = 200
results = my_first_api.search(q=query, lang=language, tweet_mode='extended', count=tweetCount)

count_all.clear()
for tweet in results:
    terms_hash = [term for term in preprocess_tweet(tweet.full_text) if term.startswith('@')]
    count_all.update(terms_hash)

top20 = count_all.most_common(20)
print(top20)

# [('@FlatironSchool', 83), ('@fulmolightning', 52), ('@pierre_rochard', 21), 
# ('@peterktodd', 19), ('@MsJisola', 17), ('@ElectrumWallet', 17), ('@BtcpayServer', 14), 
# ('@r0ckstardev', 13), ('@Blockstream', 12), ('@Excellion', 12), ('@rootzoll', 11), 
# ('@CryptoCloaks', 8), ('@CasaHODL', 7), ('@overtorment', 6), ('@CReckhow', 5), 
# ('@starkness', 4), ('@CodeNewbies', 4), ('@TeachFirst', 4), ('@jeetsidhu_', 3), ('@Snyke', 3)]
# Out:
# [('@FlatironSchool', 49), ('@MsJisola', 15), ('@RRombom', 10), ('@FlatironSch', 10), ('@impacthubHOU', 8), ('@meisuleen', 5), ('@kenanberker', 5), ('@EstherShira', 3), ('@doneil155', 3), ('@urbanplans', 3), ('@TorchonGilbert', 2), ('@FlatironLabs', 2), ('@flatironschool', 2), ('@operation_code', 2), ('@linuxacademyCOM', 2), ('@ChrisManna77', 2), ('@aviflombaum', 2), ('@TheLovettSchool', 2), ('@CaralieCS', 1), ('@LeadHerFuture', 1)]

# %% [markdown]
# Another common way to view dominant terms in a corpus of text is to visualize a wordcloud of top n terms. Here is an API reference for [WordCloud for Python](https://amueller.github.io/word_cloud/references.html).
# * Create a word cloud from top 20 mentions above to highlight who is being mentioned most.

# %%
# Visualize the word cloud for top 20 mentions everytime flatiron school gets mentioned in a tweet
import numpy as np
from PIL import Image
from os import path
import wordcloud
mask = np.array(Image.open("FS.png"))
cloud = wordcloud.WordCloud(max_font_size=50, max_words=100, background_color="white")

cloud.generate_from_frequencies(dict(top10))

plt.figure(figsize=(15,10))
plt.imshow(cloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-2f7de7f90963> in <module>()
#       3 from PIL import Image
#       4 from os import path
# ----> 5 import wordcloud
#       6 mask = np.array(Image.open("FS.png"))
#       7 cloud = wordcloud.WordCloud(max_font_size=50, max_words=100, background_color="white")
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# This looks great. Try collecting a large number of tweets using the cfietria seen previously and create a more populated word cloud. You can also customize and prettify it to your heart's content.
#
# ## From JSON to DataFrames
#
# So far, we have been processing our tweets directly from the JSON files. It may be desired for an advanced analystical experiment to store data as pandas dataframe and enjoy all the goodness of pandas, scikitlearn and buult in statistics. Let's try to select some selected parts of the tweet and save it nicely as pandas dataframe and csv file.
#
# #### Load `tweets.json`  and save following contents as pandas dataframe `tweet_json_df`
#     * id
#     * full_text
#     * favorite_count
#     * retweet_count
#     * created_at
#
# * Set some meaningful names for dataframe columns to store these values.
# * Print the dataframe head to inspect the contents
# * save data as "tweets.csv"

# %%
# Parse the JSON file, selecting above attributes for each tweet and saving as a new row in a pandas dataframe
import pandas as pd
my_tweets_list = []
with open('tweets.json', encoding='utf-8') as json_file:  
    all_data = json.load(json_file)
    for each_dictionary in all_data:
        tweet_id = each_dictionary['id']
        text = each_dictionary['full_text']
        favorite_count = each_dictionary['favorite_count']
        retweet_count = each_dictionary['retweet_count']
        created_at = each_dictionary['created_at']
        my_tweets_list.append({'tweet_id': str(tweet_id),
                             'text': str(text),
                             'favorite_count': int(favorite_count),
                             'retweet_count': int(retweet_count),
                             'created_at': created_at,
                            })
        #print(my_demo_list)
        tweet_json_df = pd.DataFrame(my_tweets_list, 
                        columns = ['tweet_id', 'text', 
                                   'favorite_count', 
                                   'retweet_count', 
                                   'created_at'])

tweet_json_df.to_csv('tweets.csv')
tweet_json_df.head()


# tweet_id	             text	                                         favorite_count	retweet_count	created_at
# 0	1056647627062661121	RT @RalstonReports: The turnout models are loo...	0	15	Sun Oct 28 20:43:20 +0000 2018
# 1	1056647041093373952	[Cheat Sheet] Python Basics For Data Science h...	2	1	Sun Oct 28 20:41:00 +0000 2018
# 2	1056640802401615872	RT @Popehat: NYT: Well, Okay, But Are People ...	0	620	Sun Oct 28 20:16:13 +0000 2018
# 3	1056639940438544384	https://t.co/txeJ3g9IMW	1	1	Sun Oct 28 20:12:47 +0000 2018
# 4	1056638994203729922	IBM and NVIDIA collaborate to expand machine l...	3	1	Sun Oct 28 20:09:02 +0000 2018
# Out:
#               tweet_id                                               text  \
# 0  1060588577602433024  RT @redsteeze: Same thing that happened to the...
# 1  1060588463798374401  My thoughts and prayers are with the families ...
# 2  1060588065238839298  RT @PodSaveAmerica: "Look at Beto O'Rourke, St...
# 3  1060588005969149952  RT @KSoltisAnderson: One more thing, and this ...
# 4  1060587972452466688  RT @realDailyWire: SALE: @BenShapiro 2024 Fact...
#
#    favorite_count  retweet_count                      created_at
# 0               0             22  Thu Nov 08 17:43:16 +0000 2018
# 1             564            190  Thu Nov 08 17:42:49 +0000 2018
# 2               0            184  Thu Nov 08 17:41:14 +0000 2018
# 3               0            127  Thu Nov 08 17:41:00 +0000 2018
# 4               0              3  Thu Nov 08 17:40:52 +0000 2018

# %% [markdown]
# So there we have it. The skills that you have learned in this lab can be used towards data journalism, data science related articles etc. These skills will also come in handy for more advanced NLP techniques like topic modelling, sentiment analysis, emoticon analysis etc.

# %% [markdown]
# ## Level Up - Optional
#
# * Try generating more wordclouds from all the examples we saw in this lab.
# * Ask yourself an analytical question and mine Twitter to get tweets, process them in tweepy and visualize the results.
# * Count emoticons for smily face, frowning face, excited face etc. and see what are people's sentiments about a specific topic of interest i.e. Brexit, War in Syria, Best actor from last Oscars etc.
# * See which Twitter member is mentioning you the most at Twitter.
# * ON-going : Repeatedly mine twitter (say once per day) on a topic of interest and collect,parse,visualize tweets to see any changing trends.

# %% [markdown]
# ## Further Reading
#
# * [Introduction to NLP](https://blog.algorithmia.com/introduction-natural-language-processing-nlp/)
# * [Python/NLTK Language Processing](http://blog.chapagain.com.np/python-nltk-twitter-sentiment-analysis-natural-language-processing-nlp/)
# * [Applying NLP to Twitter in Python](https://dzone.com/articles/applying-nlp-to-tweets-with-python)
# * [Using the Twitter API and NLP to analyze the tweets of different users.](https://towardsdatascience.com/twitter-api-and-nlp-7a386758eb31)

# %% [markdown]
# ## Summary
#
# In this lab, we saw how to collect data from twitter using OAuth and collect Tweets under for a number of different use cases. We looked at parsing the JSON file for collecting relevant information and also visualized the outcome of our processing. As a reminder, this lab is supposed to be a data engineering oriented lab, i.e. getting data ready for processing. We shall see more on NLP later in next module of the course. This lab should get you all ready for some serious experiments like sentiment analysis , predictions and classification tasks.
